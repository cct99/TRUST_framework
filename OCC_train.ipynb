# %%
import pandas as pd
from sklearn.svm import OneClassSVM
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import itertools
import joblib
import os

SIZES = {
    '1k': {'train_path': '/home/ctai42@tntech.edu/OCC/Model_training_and_inference_code/new_occ_training_data_1k_mc_15.csv',
           'models_dir': '/home/ctai42@tntech.edu/OCC/Chao_new_pretrained_mc_15_1k',
           'results_file': '/home/ctai42@tntech.edu/OCC/Chao_results_mc15/occ_hyperparameter_results_1k.csv'},
    '2k': {'train_path': '/home/ctai42@tntech.edu/OCC/Model_training_and_inference_code/new_occ_training_data_2k_mc_15.csv',
           'models_dir': '/home/ctai42@tntech.edu/OCC/Chao_new_pretrained_mc_15_2k',
           'results_file': '/home/ctai42@tntech.edu/OCC/Chao_results_mc15/occ_hyperparameter_results_2k.csv'},
    '3k': {'train_path': '/home/ctai42@tntech.edu/OCC/Model_training_and_inference_code/new_occ_training_data_3k_mc_15.csv',
           'models_dir': '/home/ctai42@tntech.edu/OCC/Chao_new_pretrained_mc_15_3k',
           'results_file': '/home/ctai42@tntech.edu/OCC/Chao_results_mc15/occ_hyperparameter_results_3k.csv'},
    '4k': {'train_path': '/home/ctai42@tntech.edu/OCC/Model_training_and_inference_code/new_occ_training_data_4k_mc_15.csv',
           'models_dir': '/home/ctai42@tntech.edu/OCC/Chao_new_pretrained_mc_15_4k',
           'results_file': '/home/ctai42@tntech.edu/OCC/Chao_results_mc15/occ_hyperparameter_results_4k.csv'},
    '5k': {'train_path': '/home/ctai42@tntech.edu/OCC/Model_training_and_inference_code/new_occ_training_data_5k_mc_15.csv',
           'models_dir': '/home/ctai42@tntech.edu/OCC/Chao_new_pretrained_mc_15_5k',
           'results_file': '/home/ctai42@tntech.edu/OCC/Chao_results_mc15/occ_hyperparameter_results_5k.csv'},
    '10k': {'train_path': '/home/ctai42@tntech.edu/OCC/Model_training_and_inference_code/new_occ_training_data_10k_mc_15.csv',
           'models_dir': '/home/ctai42@tntech.edu/OCC/Chao_new_pretrained_mc_15_10k',
           'results_file': '/home/ctai42@tntech.edu/OCC/Chao_results_mc15/occ_hyperparameter_results_10k.csv'},
    '15k': {'train_path': '/home/ctai42@tntech.edu/OCC/Model_training_and_inference_code/new_occ_training_data_15k_mc_15.csv',
           'models_dir': '/home/ctai42@tntech.edu/OCC/Chao_new_pretrained_mc_15_15k',
           'results_file': '/home/ctai42@tntech.edu/OCC/Chao_results_mc15/occ_hyperparameter_results_15k.csv'},
    '20k': {'train_path': '/home/ctai42@tntech.edu/OCC/Model_training_and_inference_code/new_occ_training_data_20k_mc_15.csv',
           'models_dir': '/home/ctai42@tntech.edu/OCC/Chao_new_pretrained_mc_15_20k',
           'results_file': '/home/ctai42@tntech.edu/OCC/Chao_results_mc15/occ_hyperparameter_results_20k.csv'}
}

TEST_FILE = "/home/ctai42@tntech.edu/OCC/Model_training_and_inference_code/new_occ_testing_data_mc_15.csv"
SCALER_BASE_PATH = "/home/ctai42@tntech.edu/OCC/Pre_Trained_Model/scaler"

# Hyperparameters
nu_values = [0.01, 0.05, 0.1, 0.2]
gamma_values = ['scale', 'auto', 0.01, 0.1, 1.0]

# Load test data 
test_data = pd.read_csv(TEST_FILE)
test_features = test_data.drop(columns=["image_num", "actual_class", "noise_level"])

def train_size_model(size_key, paths):
    print(f"\nProcessing {size_key} dataset...")
    
    # Load training data
    train_data = pd.read_csv(paths['train_path'])
    train_features = train_data.drop(columns=["image_num", "actual_class", "noise_level"])
    
    # Create and fit scaler
    scaler = StandardScaler()
    X_train = scaler.fit_transform(train_features)
    X_test = scaler.transform(test_features)
    
    # Save scaler to a folder
    scaler_file = os.path.join(SCALER_BASE_PATH, f"scaler_mc15_{size_key}.joblib")
    os.makedirs(os.path.dirname(scaler_file), exist_ok=True)
    joblib.dump(scaler, scaler_file)
    
    os.makedirs(paths['models_dir'], exist_ok=True)
    
    # Train models with different hyperparameters
    results = []
    for nu, gamma in itertools.product(nu_values, gamma_values):
        print(f"Training OCC SVM with nu={nu}, gamma={gamma}")
        oc_svm = OneClassSVM(kernel="rbf", nu=nu, gamma=gamma)
        oc_svm.fit(X_train)
        
        # Save models to models_dir
        model_file = os.path.join(paths['models_dir'], f"oc_svm_nu{nu}_gamma{gamma}.joblib")
        joblib.dump(oc_svm, model_file)
        
        y_pred = oc_svm.predict(X_test)
        y_pred = [-1 if x == -1 else 0 for x in y_pred]
        
        true_flagged = sum([1 if pred == -1 else 0 for pred in y_pred])
        false_normal = sum([1 if pred == 0 else 0 for pred in y_pred])
        accuracy = true_flagged / len(y_pred)
        
        print(f"Accuracy: {accuracy}, True Flagged: {true_flagged}, False Normal: {false_normal}")
        
        results.append({
            "size": size_key,
            "nu": nu,
            "gamma": gamma,
            "accuracy": accuracy,
            "pred_flagged": true_flagged,
            "pred_normal": false_normal,
            "model_file": model_file
        })
    
    results_df = pd.DataFrame(results)
    os.makedirs(os.path.dirname(paths['results_file']), exist_ok=True)
    results_df.to_csv(paths['results_file'], index=False)
    
    return results_df

# Run training for all sizes
all_results = []
for size_key, paths in SIZES.items():
    size_results = train_size_model(size_key, paths)
    all_results.append(size_results)

# Combine and save all results
combined_results = pd.concat(all_results)
combined_results_file = "/home/ctai42@tntech.edu/OCC/Chao_results_mc15/combined_hyperparameter_results.csv"
combined_results.to_csv(combined_results_file, index=False)
# Out:
# Processing 1k dataset...
# Training OCC SVM with nu=0.01, gamma=scale
# Accuracy: 0.112, True Flagged: 112, False Normal: 888
# Training OCC SVM with nu=0.01, gamma=auto
# Accuracy: 0.112, True Flagged: 112, False Normal: 888
# Training OCC SVM with nu=0.01, gamma=0.01
# Accuracy: 0.03, True Flagged: 30, False Normal: 970
# Training OCC SVM with nu=0.01, gamma=0.1
# Accuracy: 0.394, True Flagged: 394, False Normal: 606
# Training OCC SVM with nu=0.01, gamma=1.0
# Accuracy: 0.888, True Flagged: 888, False Normal: 112
# Training OCC SVM with nu=0.05, gamma=scale
# Accuracy: 0.127, True Flagged: 127, False Normal: 873
# Training OCC SVM with nu=0.05, gamma=auto
# Accuracy: 0.127, True Flagged: 127, False Normal: 873
# Training OCC SVM with nu=0.05, gamma=0.01
# Accuracy: 0.092, True Flagged: 92, False Normal: 908
# Training OCC SVM with nu=0.05, gamma=0.1
# Accuracy: 0.396, True Flagged: 396, False Normal: 604
# Training OCC SVM with nu=0.05, gamma=1.0
# Accuracy: 0.889, True Flagged: 889, False Normal: 111
# Training OCC SVM with nu=0.1, gamma=scale
# Accuracy: 0.183, True Flagged: 183, False Normal: 817
# Training OCC SVM with nu=0.1, gamma=auto
# Accuracy: 0.183, True Flagged: 183, False Normal: 817
# Training OCC SVM with nu=0.1, gamma=0.01
# Accuracy: 0.181, True Flagged: 181, False Normal: 819
# Training OCC SVM with nu=0.1, gamma=0.1
# Accuracy: 0.403, True Flagged: 403, False Normal: 597
# Training OCC SVM with nu=0.1, gamma=1.0
# Accuracy: 0.889, True Flagged: 889, False Normal: 111
# Training OCC SVM with nu=0.2, gamma=scale
# Accuracy: 0.334, True Flagged: 334, False Normal: 666
# Training OCC SVM with nu=0.2, gamma=auto
# Accuracy: 0.334, True Flagged: 334, False Normal: 666
# Training OCC SVM with nu=0.2, gamma=0.01
# Accuracy: 0.343, True Flagged: 343, False Normal: 657
# Training OCC SVM with nu=0.2, gamma=0.1
# Accuracy: 0.525, True Flagged: 525, False Normal: 475
# Training OCC SVM with nu=0.2, gamma=1.0
# Accuracy: 0.889, True Flagged: 889, False Normal: 111
#
# Processing 2k dataset...
# Training OCC SVM with nu=0.01, gamma=scale
# Accuracy: 0.056, True Flagged: 56, False Normal: 944
# Training OCC SVM with nu=0.01, gamma=auto
# Accuracy: 0.056, True Flagged: 56, False Normal: 944
# Training OCC SVM with nu=0.01, gamma=0.01
# Accuracy: 0.015, True Flagged: 15, False Normal: 985
# Training OCC SVM with nu=0.01, gamma=0.1
# Accuracy: 0.223, True Flagged: 223, False Normal: 777
# Training OCC SVM with nu=0.01, gamma=1.0
# Accuracy: 0.827, True Flagged: 827, False Normal: 173
# Training OCC SVM with nu=0.05, gamma=scale
# Accuracy: 0.095, True Flagged: 95, False Normal: 905
# Training OCC SVM with nu=0.05, gamma=auto
# Accuracy: 0.095, True Flagged: 95, False Normal: 905
# Training OCC SVM with nu=0.05, gamma=0.01
# Accuracy: 0.08, True Flagged: 80, False Normal: 920
# Training OCC SVM with nu=0.05, gamma=0.1
# Accuracy: 0.223, True Flagged: 223, False Normal: 777
# Training OCC SVM with nu=0.05, gamma=1.0
# Accuracy: 0.822, True Flagged: 822, False Normal: 178
# Training OCC SVM with nu=0.1, gamma=scale
# Accuracy: 0.15, True Flagged: 150, False Normal: 850
# Training OCC SVM with nu=0.1, gamma=auto
# Accuracy: 0.15, True Flagged: 150, False Normal: 850
# Training OCC SVM with nu=0.1, gamma=0.01
# Accuracy: 0.167, True Flagged: 167, False Normal: 833
# Training OCC SVM with nu=0.1, gamma=0.1
# Accuracy: 0.237, True Flagged: 237, False Normal: 763
# Training OCC SVM with nu=0.1, gamma=1.0
# Accuracy: 0.822, True Flagged: 822, False Normal: 178
# Training OCC SVM with nu=0.2, gamma=scale
# Accuracy: 0.315, True Flagged: 315, False Normal: 685
# Training OCC SVM with nu=0.2, gamma=auto
# Accuracy: 0.315, True Flagged: 315, False Normal: 685
# Training OCC SVM with nu=0.2, gamma=0.01
# Accuracy: 0.328, True Flagged: 328, False Normal: 672
# Training OCC SVM with nu=0.2, gamma=0.1
# Accuracy: 0.384, True Flagged: 384, False Normal: 616
# Training OCC SVM with nu=0.2, gamma=1.0
# Accuracy: 0.822, True Flagged: 822, False Normal: 178
#
# Processing 3k dataset...
# Training OCC SVM with nu=0.01, gamma=scale
# Accuracy: 0.034, True Flagged: 34, False Normal: 966
# Training OCC SVM with nu=0.01, gamma=auto
# Accuracy: 0.034, True Flagged: 34, False Normal: 966
# Training OCC SVM with nu=0.01, gamma=0.01
# Accuracy: 0.013, True Flagged: 13, False Normal: 987
# Training OCC SVM with nu=0.01, gamma=0.1
# Accuracy: 0.163, True Flagged: 163, False Normal: 837
# Training OCC SVM with nu=0.01, gamma=1.0
# Accuracy: 0.779, True Flagged: 779, False Normal: 221
# Training OCC SVM with nu=0.05, gamma=scale
# Accuracy: 0.069, True Flagged: 69, False Normal: 931
# Training OCC SVM with nu=0.05, gamma=auto
# Accuracy: 0.069, True Flagged: 69, False Normal: 931
# Training OCC SVM with nu=0.05, gamma=0.01
# Accuracy: 0.067, True Flagged: 67, False Normal: 933
# Training OCC SVM with nu=0.05, gamma=0.1
# Accuracy: 0.162, True Flagged: 162, False Normal: 838
# Training OCC SVM with nu=0.05, gamma=1.0
# Accuracy: 0.778, True Flagged: 778, False Normal: 222
# Training OCC SVM with nu=0.1, gamma=scale
# Accuracy: 0.141, True Flagged: 141, False Normal: 859
# Training OCC SVM with nu=0.1, gamma=auto
# Accuracy: 0.141, True Flagged: 141, False Normal: 859
# Training OCC SVM with nu=0.1, gamma=0.01
# Accuracy: 0.154, True Flagged: 154, False Normal: 846
# Training OCC SVM with nu=0.1, gamma=0.1
# Accuracy: 0.215, True Flagged: 215, False Normal: 785
# Training OCC SVM with nu=0.1, gamma=1.0
# Accuracy: 0.779, True Flagged: 779, False Normal: 221
# Training OCC SVM with nu=0.2, gamma=scale
# Accuracy: 0.327, True Flagged: 327, False Normal: 673
# Training OCC SVM with nu=0.2, gamma=auto
# Accuracy: 0.327, True Flagged: 327, False Normal: 673
# Training OCC SVM with nu=0.2, gamma=0.01
# Accuracy: 0.338, True Flagged: 338, False Normal: 662
# Training OCC SVM with nu=0.2, gamma=0.1
# Accuracy: 0.389, True Flagged: 389, False Normal: 611
# Training OCC SVM with nu=0.2, gamma=1.0
# Accuracy: 0.779, True Flagged: 779, False Normal: 221
#
# Processing 4k dataset...
# Training OCC SVM with nu=0.01, gamma=scale
# Accuracy: 0.03, True Flagged: 30, False Normal: 970
# Training OCC SVM with nu=0.01, gamma=auto
# Accuracy: 0.03, True Flagged: 30, False Normal: 970
# Training OCC SVM with nu=0.01, gamma=0.01
# Accuracy: 0.009, True Flagged: 9, False Normal: 991
# Training OCC SVM with nu=0.01, gamma=0.1
# Accuracy: 0.132, True Flagged: 132, False Normal: 868
# Training OCC SVM with nu=0.01, gamma=1.0
# Accuracy: 0.76, True Flagged: 760, False Normal: 240
# Training OCC SVM with nu=0.05, gamma=scale
# Accuracy: 0.08, True Flagged: 80, False Normal: 920
# Training OCC SVM with nu=0.05, gamma=auto
# Accuracy: 0.08, True Flagged: 80, False Normal: 920
# Training OCC SVM with nu=0.05, gamma=0.01
# Accuracy: 0.068, True Flagged: 68, False Normal: 932
# Training OCC SVM with nu=0.05, gamma=0.1
# Accuracy: 0.145, True Flagged: 145, False Normal: 855
# Training OCC SVM with nu=0.05, gamma=1.0
# Accuracy: 0.757, True Flagged: 757, False Normal: 243
# Training OCC SVM with nu=0.1, gamma=scale
# Accuracy: 0.139, True Flagged: 139, False Normal: 861
# Training OCC SVM with nu=0.1, gamma=auto
# Accuracy: 0.139, True Flagged: 139, False Normal: 861
# Training OCC SVM with nu=0.1, gamma=0.01
# Accuracy: 0.145, True Flagged: 145, False Normal: 855
# Training OCC SVM with nu=0.1, gamma=0.1
# Accuracy: 0.202, True Flagged: 202, False Normal: 798
# Training OCC SVM with nu=0.1, gamma=1.0
# Accuracy: 0.757, True Flagged: 757, False Normal: 243
# Training OCC SVM with nu=0.2, gamma=scale
# Accuracy: 0.296, True Flagged: 296, False Normal: 704
# Training OCC SVM with nu=0.2, gamma=auto
# Accuracy: 0.296, True Flagged: 296, False Normal: 704
# Training OCC SVM with nu=0.2, gamma=0.01
# Accuracy: 0.315, True Flagged: 315, False Normal: 685
# Training OCC SVM with nu=0.2, gamma=0.1
# Accuracy: 0.352, True Flagged: 352, False Normal: 648
# Training OCC SVM with nu=0.2, gamma=1.0
# Accuracy: 0.757, True Flagged: 757, False Normal: 243
#
# Processing 5k dataset...
# Training OCC SVM with nu=0.01, gamma=scale
# Accuracy: 0.018, True Flagged: 18, False Normal: 982
# Training OCC SVM with nu=0.01, gamma=auto
# Accuracy: 0.018, True Flagged: 18, False Normal: 982
# Training OCC SVM with nu=0.01, gamma=0.01
# Accuracy: 0.009, True Flagged: 9, False Normal: 991
# Training OCC SVM with nu=0.01, gamma=0.1
# Accuracy: 0.091, True Flagged: 91, False Normal: 909
# Training OCC SVM with nu=0.01, gamma=1.0
# Accuracy: 0.734, True Flagged: 734, False Normal: 266
# Training OCC SVM with nu=0.05, gamma=scale
# Accuracy: 0.052, True Flagged: 52, False Normal: 948
# Training OCC SVM with nu=0.05, gamma=auto
# Accuracy: 0.052, True Flagged: 52, False Normal: 948
# Training OCC SVM with nu=0.05, gamma=0.01
# Accuracy: 0.052, True Flagged: 52, False Normal: 948
# Training OCC SVM with nu=0.05, gamma=0.1
# Accuracy: 0.104, True Flagged: 104, False Normal: 896
# Training OCC SVM with nu=0.05, gamma=1.0
# Accuracy: 0.736, True Flagged: 736, False Normal: 264
# Training OCC SVM with nu=0.1, gamma=scale
# Accuracy: 0.126, True Flagged: 126, False Normal: 874
# Training OCC SVM with nu=0.1, gamma=auto
# Accuracy: 0.126, True Flagged: 126, False Normal: 874
# Training OCC SVM with nu=0.1, gamma=0.01
# Accuracy: 0.146, True Flagged: 146, False Normal: 854
# Training OCC SVM with nu=0.1, gamma=0.1
# Accuracy: 0.162, True Flagged: 162, False Normal: 838
# Training OCC SVM with nu=0.1, gamma=1.0
# Accuracy: 0.736, True Flagged: 736, False Normal: 264
# Training OCC SVM with nu=0.2, gamma=scale
# Accuracy: 0.298, True Flagged: 298, False Normal: 702
# Training OCC SVM with nu=0.2, gamma=auto
# Accuracy: 0.298, True Flagged: 298, False Normal: 702
# Training OCC SVM with nu=0.2, gamma=0.01
# Accuracy: 0.316, True Flagged: 316, False Normal: 684
# Training OCC SVM with nu=0.2, gamma=0.1
# Accuracy: 0.357, True Flagged: 357, False Normal: 643
# Training OCC SVM with nu=0.2, gamma=1.0
# Accuracy: 0.736, True Flagged: 736, False Normal: 264
#
# Processing 10k dataset...
# Training OCC SVM with nu=0.01, gamma=scale
# Accuracy: 0.009, True Flagged: 9, False Normal: 991
# Training OCC SVM with nu=0.01, gamma=auto
# Accuracy: 0.009, True Flagged: 9, False Normal: 991
# Training OCC SVM with nu=0.01, gamma=0.01
# Accuracy: 0.007, True Flagged: 7, False Normal: 993
# Training OCC SVM with nu=0.01, gamma=0.1
# Accuracy: 0.061, True Flagged: 61, False Normal: 939
# Training OCC SVM with nu=0.01, gamma=1.0
# Accuracy: 0.676, True Flagged: 676, False Normal: 324
# Training OCC SVM with nu=0.05, gamma=scale
# Accuracy: 0.046, True Flagged: 46, False Normal: 954
# Training OCC SVM with nu=0.05, gamma=auto
# Accuracy: 0.046, True Flagged: 46, False Normal: 954
# Training OCC SVM with nu=0.05, gamma=0.01
# Accuracy: 0.057, True Flagged: 57, False Normal: 943
# Training OCC SVM with nu=0.05, gamma=0.1
# Accuracy: 0.08, True Flagged: 80, False Normal: 920
# Training OCC SVM with nu=0.05, gamma=1.0
# Accuracy: 0.677, True Flagged: 677, False Normal: 323
# Training OCC SVM with nu=0.1, gamma=scale
# Accuracy: 0.11, True Flagged: 110, False Normal: 890
# Training OCC SVM with nu=0.1, gamma=auto
# Accuracy: 0.11, True Flagged: 110, False Normal: 890
# Training OCC SVM with nu=0.1, gamma=0.01
# Accuracy: 0.129, True Flagged: 129, False Normal: 871
# Training OCC SVM with nu=0.1, gamma=0.1
# Accuracy: 0.143, True Flagged: 143, False Normal: 857
# Training OCC SVM with nu=0.1, gamma=1.0
# Accuracy: 0.676, True Flagged: 676, False Normal: 324
# Training OCC SVM with nu=0.2, gamma=scale
# Accuracy: 0.261, True Flagged: 261, False Normal: 739
# Training OCC SVM with nu=0.2, gamma=auto
# Accuracy: 0.261, True Flagged: 261, False Normal: 739
# Training OCC SVM with nu=0.2, gamma=0.01
# Accuracy: 0.294, True Flagged: 294, False Normal: 706
# Training OCC SVM with nu=0.2, gamma=0.1
# Accuracy: 0.309, True Flagged: 309, False Normal: 691
# Training OCC SVM with nu=0.2, gamma=1.0
# Accuracy: 0.675, True Flagged: 675, False Normal: 325
#
# Processing 15k dataset...
# Training OCC SVM with nu=0.01, gamma=scale
# Accuracy: 0.009, True Flagged: 9, False Normal: 991
# Training OCC SVM with nu=0.01, gamma=auto
# Accuracy: 0.009, True Flagged: 9, False Normal: 991
# Training OCC SVM with nu=0.01, gamma=0.01
# Accuracy: 0.006, True Flagged: 6, False Normal: 994
# Training OCC SVM with nu=0.01, gamma=0.1
# Accuracy: 0.05, True Flagged: 50, False Normal: 950
# Training OCC SVM with nu=0.01, gamma=1.0
# Accuracy: 0.652, True Flagged: 652, False Normal: 348
# Training OCC SVM with nu=0.05, gamma=scale
# Accuracy: 0.05, True Flagged: 50, False Normal: 950
# Training OCC SVM with nu=0.05, gamma=auto
# Accuracy: 0.05, True Flagged: 50, False Normal: 950
# Training OCC SVM with nu=0.05, gamma=0.01
# Accuracy: 0.05, True Flagged: 50, False Normal: 950
# Training OCC SVM with nu=0.05, gamma=0.1
# Accuracy: 0.079, True Flagged: 79, False Normal: 921
# Training OCC SVM with nu=0.05, gamma=1.0
# Accuracy: 0.649, True Flagged: 649, False Normal: 351
# Training OCC SVM with nu=0.1, gamma=scale
# Accuracy: 0.11, True Flagged: 110, False Normal: 890
# Training OCC SVM with nu=0.1, gamma=auto
# Accuracy: 0.11, True Flagged: 110, False Normal: 890
# Training OCC SVM with nu=0.1, gamma=0.01
# Accuracy: 0.125, True Flagged: 125, False Normal: 875
# Training OCC SVM with nu=0.1, gamma=0.1
# Accuracy: 0.142, True Flagged: 142, False Normal: 858
# Training OCC SVM with nu=0.1, gamma=1.0
# Accuracy: 0.649, True Flagged: 649, False Normal: 351
# Training OCC SVM with nu=0.2, gamma=scale
# Accuracy: 0.247, True Flagged: 247, False Normal: 753
# Training OCC SVM with nu=0.2, gamma=auto
# Accuracy: 0.247, True Flagged: 247, False Normal: 753
# Training OCC SVM with nu=0.2, gamma=0.01
# Accuracy: 0.286, True Flagged: 286, False Normal: 714
# Training OCC SVM with nu=0.2, gamma=0.1
# Accuracy: 0.298, True Flagged: 298, False Normal: 702
# Training OCC SVM with nu=0.2, gamma=1.0
# Accuracy: 0.65, True Flagged: 650, False Normal: 350
#
# Processing 20k dataset...
# Training OCC SVM with nu=0.01, gamma=scale
# Accuracy: 0.01, True Flagged: 10, False Normal: 990
# Training OCC SVM with nu=0.01, gamma=auto
# Accuracy: 0.01, True Flagged: 10, False Normal: 990
# Training OCC SVM with nu=0.01, gamma=0.01
# Accuracy: 0.006, True Flagged: 6, False Normal: 994
# Training OCC SVM with nu=0.01, gamma=0.1
# Accuracy: 0.029, True Flagged: 29, False Normal: 971
# Training OCC SVM with nu=0.01, gamma=1.0
# Accuracy: 0.628, True Flagged: 628, False Normal: 372
# Training OCC SVM with nu=0.05, gamma=scale
# Accuracy: 0.043, True Flagged: 43, False Normal: 957
# Training OCC SVM with nu=0.05, gamma=auto
# Accuracy: 0.043, True Flagged: 43, False Normal: 957
# Training OCC SVM with nu=0.05, gamma=0.01
# Accuracy: 0.053, True Flagged: 53, False Normal: 947
# Training OCC SVM with nu=0.05, gamma=0.1
# Accuracy: 0.061, True Flagged: 61, False Normal: 939
# Training OCC SVM with nu=0.05, gamma=1.0
# Accuracy: 0.629, True Flagged: 629, False Normal: 371
# Training OCC SVM with nu=0.1, gamma=scale
# Accuracy: 0.106, True Flagged: 106, False Normal: 894
# Training OCC SVM with nu=0.1, gamma=auto
# Accuracy: 0.106, True Flagged: 106, False Normal: 894
# Training OCC SVM with nu=0.1, gamma=0.01
# Accuracy: 0.128, True Flagged: 128, False Normal: 872
# Training OCC SVM with nu=0.1, gamma=0.1
# Accuracy: 0.137, True Flagged: 137, False Normal: 863
# Training OCC SVM with nu=0.1, gamma=1.0
# Accuracy: 0.628, True Flagged: 628, False Normal: 372
# Training OCC SVM with nu=0.2, gamma=scale
# Accuracy: 0.261, True Flagged: 261, False Normal: 739
# Training OCC SVM with nu=0.2, gamma=auto
# Accuracy: 0.261, True Flagged: 261, False Normal: 739
# Training OCC SVM with nu=0.2, gamma=0.01
# Accuracy: 0.294, True Flagged: 294, False Normal: 706
# Training OCC SVM with nu=0.2, gamma=0.1
# Accuracy: 0.299, True Flagged: 299, False Normal: 701
# Training OCC SVM with nu=0.2, gamma=1.0
# Accuracy: 0.629, True Flagged: 629, False Normal: 371
